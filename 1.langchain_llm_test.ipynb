# %%
from dotenv import load_dotenv 

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm=ChatOpenAI()

# %%
ai_msg=llm.invoke("안녕하세요!")

# %%
ai_msg.content
# Out:
# '안녕하세요! 무엇을 도와드릴까요? 😊'
